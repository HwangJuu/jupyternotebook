# %% [markdown]
# ### area plot(면적 그래프)
# - NaN 값이 있으면 자동으로 0으로 채워짐
# - 기본값으로 누적시켜서 작성됨

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 한글처리
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(10,4), columns=list('abcd'))
df.head()
# Out:
#           a         b         c         d
# 0  0.488064  0.623758  0.193284  0.711151
# 1  0.992875  0.290006  0.545089  0.157635
# 2  0.881516  0.221446  0.149924  0.314884
# 3  0.115610  0.935151  0.031783  0.980620
# 4  0.989625  0.155849  0.252178  0.995684

# %%
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
df.plot.area(stacked=False)
# Out:
# <AxesSubplot:>

# %%
# 그리드 옵션
df.plot.area(stacked=False, grid = True)
# Out:
# <AxesSubplot:>
