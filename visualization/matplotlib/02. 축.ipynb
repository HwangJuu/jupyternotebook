# %% [markdown]
# ## matplotlib (https://matplotlib.org/stable/index)
#
# - 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pylab as plt

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
x = [1,2,3]
y = [2,4,8]

# %%
plt.title("꺽은선 그래프", fontdict={"size":20})
g = plt.plot(x,y)

# %% [markdown]
# ### 축설정
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlabel.html
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylabel.html

# %% [markdown]
# #### 1. 이름 설정
# ><b>1) xlabel(), ylabel()</b>

# %%
plt.title("꺽은선 그래프", fontdict={"size":20})
plt.xlabel("X 축")
plt.ylabel("Y 축")
g = plt.plot(x,y)

# %% [markdown]
# ><b>2) 이름 및 다양한 설정</b>

# %% [markdown]
# matplotlib.pyplot.xlabel(xlabel, fontdict=None, labelpad=None, *, loc=None, **kwargs)
#
# - fontdict : font 설정을 dict 구조로 설정
# - labelpad : default 4.0 설정됨(label과 차트 사이의 간격)
# - **kwargs(?)
#     - color : rgb설정, 색상명 가능
# - loc : 축 이름 위치 설정('left', 'center', 'right'),  y 축 (top, bottom, center)

# %%
plt.title("꺽은선 그래프", fontdict={"size":20})
plt.xlabel("X 축", color='red', loc = 'right')
plt.ylabel("Y 축", color = '#00aa00', loc='top')
g = plt.plot(x,y)

# %%
# 컴퓨터에서 사용할 수 있는 폰트 확인 방법
import matplotlib.font_manager as fm
fm.fontManager.ttflist

[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Sans',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'DejaVu Serif Display',
#  'cmmi10',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'STIXSizeFiveSym',
#  'STIXSizeTwoSym',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'cmb10',
#  'DejaVu Sans',
#  'STIXSizeFourSym',
#  'DejaVu Sans Display',
#  'STIXSizeThreeSym',
#  'cmss10',
#  'STIXSizeFourSym',
#  'cmtt10',
#  'STIXNonUnicode',
#  'cmr10',
#  'DejaVu Serif',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'STIXGeneral',
#  'cmex10',
#  'STIXSizeThreeSym',
#  'cmsy10',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXSizeOneSym',
#  'Bell MT',
#  'Gigi',
#  'Segoe UI',
#  'HyhwpEQ',
#  'Rockwell',
#  'Bernard MT Condensed',
#  'Goudy Old Style',
#  'MingLiU-ExtB',
#  'Microsoft YaHei',
#  'Franklin Gothic Medium',
#  'STXihei',
#  'Curlz MT',
#  'Segoe UI Historic',
#  'Corbel',
#  'Calibri',
#  'Bookman Old Style',
#  'Bodoni MT',
#  'Goudy Old Style',
#  'HYMyeongJo-Extra',
#  'Corbel',
#  'Book Antiqua',
#  'Constantia',
#  'Franklin Gothic Book',
#  'HYPost-Medium',
#  'Calibri',
#  'Lucida Fax',
#  'HYPost-Light',
#  'Bookshelf Symbol 7',
#  'Blackadder ITC',
#  'Microsoft Uighur',
#  'Parchment',
#  'Consolas',
#  'Courier New',
#  'Franklin Gothic Demi',
#  'Book Antiqua',
#  'Bell MT',
#  'Lucida Sans Unicode',
#  'Lucida Sans',
#  'Microsoft YaHei',
#  'Garamond',
#  'HancomEQN',
#  'Impact',
#  'Lucida Sans Typewriter',
#  'Lucida Sans',
#  'Consolas',
#  'Microsoft Yi Baiti',
#  'Dubai',
#  'Verdana',
#  'Segoe UI',
#  'Century Schoolbook',
#  'Segoe UI',
#  'Californian FB',
#  'Myanmar Text',
#  'Monotype Corsiva',
#  'Arial',
#  'Bodoni MT',
#  'Palatino Linotype',
#  'Playbill',
#  'Sitka',
#  'Hancom Hoonminjeongeum_H',
#  'NewJumja',
#  'Footlight MT Light',
#  'Consolas',
#  'Georgia',
#  'Bell MT',
#  'Trebuchet MS',
#  'Arial',
#  'Tw Cen MT Condensed',
#  'Californian FB',
#  'Segoe UI',
#  'Magic R',
#  'Segoe Fluent Icons',
#  'OCR A Extended',
#  'Snap ITC',
#  'MT Extra',
#  'HYPMokGak-Bold',
#  'Garamond',
#  'FZYaoTi',
#  'New Gulim',
#  'Yu Gothic',
#  'Felix Titling',
#  'STLiti',
#  'Microsoft PhagsPa',
#  'HYSinMyeongJo-Medium',
#  'Microsoft YaHei',
#  'Hancom Gothic',
#  'Broadway',
#  'Franklin Gothic Demi Cond',
#  'STKaiti',
#  'Gill Sans Ultra Bold Condensed',
#  'Perpetua',
#  'Times New Roman',
#  'Old English Text MT',
#  'SimSun',
#  'Bahnschrift',
#  'Ebrima',
#  'Britannic Bold',
#  'Franklin Gothic Medium',
#  'Sylfaen',
#  'Han Santteut Dotum',
#  'Calibri',
#  'Century Schoolbook',
#  'Tw Cen MT',
#  'Garamond',
#  'Nirmala UI',
#  'Showcard Gothic',
#  'Cambria',
#  'Bookman Old Style',
#  'Hancom Hoonminjeongeum_V',
#  'Times New Roman',
#  'Webdings',
#  'Century Gothic',
#  'MV Boli',
#  'Yu Gothic',
#  'Bodoni MT',
#  'STXinwei',
#  'Segoe Print',
#  'Batang',
#  'Gill Sans MT',
#  'Californian FB',
#  'Microsoft JhengHei',
#  'Bodoni MT',
#  'Lucida Sans Typewriter',
#  'Microsoft Himalaya',
#  'Wingdings 3',
#  'Franklin Gothic Demi',
#  'LiSu',
#  'Lucida Fax',
#  'Lucida Sans',
#  'Verdana',
#  'Candara',
#  'Trebuchet MS',
#  'Brush Script MT',
#  'Comic Sans MS',
#  'Lucida Sans Typewriter',
#  'Gill Sans MT',
#  'Lucida Bright',
#  'Lucida Sans Typewriter',
#  'Calibri',
#  'Yu Gothic',
#  'HYGungSo-Bold',
#  'Kunstler Script',
#  'Magneto',
#  'Bauhaus 93',
#  'Rockwell',
#  'YouYuan',
#  'HYGothic-Extra',
#  'Berlin Sans FB Demi',
#  'Bodoni MT',
#  'Tw Cen MT',
#  'Book Antiqua',
#  'Niagara Engraved',
#  'Palatino Linotype',
#  'Elephant',
#  'HYGothic-Medium',
#  'Eras Demi ITC',
#  'Wingdings 2',
#  'D2Coding',
#  'Candara',
#  'Goudy Old Style',
#  'Trebuchet MS',
#  'Candara',
#  'Perpetua Titling MT',
#  'Century Gothic',
#  'Vladimir Script',
#  'Script MT Bold',
#  'Bodoni MT',
#  'MS Outlook',
#  'STFangsong',
#  'Lucida Bright',
#  'Myanmar Text',
#  'Franklin Gothic Heavy',
#  'Colonna MT',
#  'Lucida Bright',
#  'Juice ITC',
#  'Hancom MalangMalang',
#  'Bodoni MT',
#  'HCR Dotum',
#  'Tw Cen MT Condensed',
#  'Tahoma',
#  'Microsoft Sans Serif',
#  'Eras Bold ITC',
#  'MS Gothic',
#  'NanumGothic',
#  'Bodoni MT',
#  'Perpetua',
#  'Onyx',
#  'MS Reference Sans Serif',
#  'Gulim',
#  'Ami R',
#  'Haettenschweiler',
#  'Copperplate Gothic Bold',
#  'Comic Sans MS',
#  'Tempus Sans ITC',
#  'Berlin Sans FB',
#  'D2Coding ligature',
#  'Segoe UI',
#  'Microsoft Uighur',
#  'Courier New',
#  'Segoe Script',
#  'Gadugi',
#  'Lucida Sans',
#  'Times New Roman',
#  'Segoe UI',
#  'Microsoft Tai Le',
#  'Microsoft JhengHei',
#  'Microsoft New Tai Lue',
#  'Gadugi',
#  'Gloucester MT Extra Condensed',
#  'Corbel',
#  'Georgia',
#  'Harrington',
#  'FZShuTi',
#  'Gill Sans MT Ext Condensed Bold',
#  'Gill Sans Ultra Bold',
#  'Cambria',
#  'Elephant',
#  'Segoe UI Variable',
#  'Courier New',
#  'Lucida Fax',
#  'Lucida Calligraphy',
#  'Century Schoolbook',
#  'Symbol',
#  'Pristina',
#  'Lucida Bright',
#  'Nirmala UI',
#  'Poor Richard',
#  'Edwardian Script ITC',
#  'Arial',
#  'Rockwell Condensed',
#  'Pyunji R',
#  'Dubai',
#  'Palace Script MT',
#  'Perpetua',
#  'STCaiyun',
#  'Cambria',
#  'Cambria',
#  'Rockwell Condensed',
#  'Constantia',
#  'Castellar',
#  'MoeumT R',
#  'Papyrus',
#  'Leelawadee UI',
#  'Rockwell',
#  'Bodoni MT',
#  'Cooper Black',
#  'Rockwell',
#  'Tahoma',
#  'NanumGothic',
#  'D2Coding',
#  'Constantia',
#  'Segoe UI',
#  'HCR Batang ExtB',
#  'Bodoni MT',
#  'Centaur',
#  'HoloLens MDL2 Assets',
#  'Harlow Solid Italic',
#  'STXingkai',
#  'Gill Sans MT Condensed',
#  'Leelawadee',
#  'Segoe UI',
#  'Bookman Old Style',
#  'Engravers MT',
#  'Calibri',
#  'HCR Batang',
#  'Microsoft New Tai Lue',
#  'Corbel',
#  'Franklin Gothic Heavy',
#  'Dubai',
#  'Gill Sans MT',
#  'Hancom Gothic',
#  'Wide Latin',
#  'HYHeadLine-Medium',
#  'Comic Sans MS',
#  'STHupo',
#  'Forte',
#  'Georgia',
#  'Informal Roman',
#  'Algerian',
#  'Courier New',
#  'Calisto MT',
#  'Freestyle Script',
#  'Bradley Hand ITC',
#  'Microsoft Tai Le',
#  'Arial',
#  'SimSun-ExtB',
#  'Baskerville Old Face',
#  'Calisto MT',
#  'Malgun Gothic',
#  'Calisto MT',
#  'Lucida Fax',
#  'Marlett',
#  'Segoe UI Emoji',
#  'Mistral',
#  'Goudy Stout',
#  'Calibri',
#  'Corbel',
#  'Candara',
#  'Comic Sans MS',
#  'High Tower Text',
#  'Ebrima',
#  'Leelawadee',
#  'Mongolian Baiti',
#  'Times New Roman',
#  'Hancom MalangMalang',
#  'Viner Hand ITC',
#  'Chiller',
#  'Tw Cen MT Condensed Extra Bold',
#  'Leelawadee UI',
#  'Segoe UI',
#  'Agency FB',
#  'Gabriola',
#  'Sitka',
#  'Segoe UI Symbol',
#  'Microsoft JhengHei',
#  'Modern No. 20',
#  'Yet R',
#  'Georgia',
#  'Century',
#  'Han Santteut Dotum',
#  'Tw Cen MT',
#  'STZhongsong',
#  'Lucida Handwriting',
#  'Dubai',
#  'Headline R',
#  'Palatino Linotype',
#  'Imprint MT Shadow',
#  'Bookman Old Style',
#  'Corbel',
#  'Niagara Solid',
#  'Arial',
#  'Century Schoolbook',
#  'Franklin Gothic Medium Cond',
#  'Rage Italic',
#  'Jokerman',
#  'Segoe Print',
#  'Yu Gothic',
#  'Consolas',
#  'HCR Batang Ext',
#  'HYGraphic-Medium',
#  'Lucida Console',
#  'Haan Wing2',
#  'Stencil',
#  'Franklin Gothic Book',
#  'Ink Free',
#  'Arial',
#  'Candara',
#  'Berlin Sans FB',
#  'Malgun Gothic',
#  'HCR Dotum',
#  'Palatino Linotype',
#  'Arial',
#  'Segoe UI',
#  'Maiandra GD',
#  'STSong',
#  'Perpetua',
#  'Segoe MDL2 Assets',
#  'Ravie',
#  'Tw Cen MT',
#  'Bodoni MT',
#  'High Tower Text',
#  'Nirmala UI',
#  'NanumGothic',
#  'Century Gothic',
#  'Leelawadee UI',
#  'Constantia',
#  'French Script MT',
#  'Arial Rounded MT Bold',
#  'Trebuchet MS',
#  'Eras Medium ITC',
#  'Microsoft PhagsPa',
#  'Agency FB',
#  'Segoe UI',
#  'Perpetua Titling MT',
#  'Candara',
#  'HCR Dotum Ext',
#  'Malgun Gothic',
#  'HCR Batang',
#  'Wingdings',
#  'Vivaldi',
#  'Copperplate Gothic Light',
#  'HCR Batang ExtB',
#  'Arial',
#  'Eras Light ITC',
#  'Verdana',
#  'MS Reference Specialty',
#  'Book Antiqua',
#  'Century Gothic',
#  'Segoe UI',
#  'Rockwell Extra Bold',
#  'Matura MT Script Capitals',
#  'Calisto MT',
#  'Kristen ITC',
#  'Verdana',
#  'HYShortSamul-Medium',
#  'Gill Sans MT',
#  'Arial',
#  'Javanese Text',
#  'Segoe Script']

# %%
fontdict1 = {'family' : 'serif','color':'b','weight':'bold','size':14}
fontdict2 = {'family' : 'Consolas','color':'deeppink','weight':'bold','size':16}

plt.title("꺽은선 그래프", fontdict={"size":20})
plt.xlabel("X", loc = 'right', fontdict=fontdict1)
plt.ylabel("Y", loc='top', fontdict=fontdict2)
g = plt.plot(x,y)

# %%
fontdict1 = {'family' : 'serif','color':'b','weight':'bold','size':14}
fontdict2 = {'family' : 'Consolas','color':'deeppink','weight':'bold','size':16}

plt.title("꺽은선 그래프", fontdict={"size":20})
plt.xlabel("X", loc = 'right', fontdict=fontdict1, labelpad=15)
plt.ylabel("Y", loc='top', fontdict=fontdict2 , labelpad=20)
g = plt.plot(x,y)

# %% [markdown]
# #### 2. 축 눈금 설정 - xticks(), yticks()

# %%
g = plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xticks([1,2,3])
plt.yticks([3,6,9,12])
# plt.show()
# Out:
# ([<matplotlib.axis.YTick at 0x1fef558c490>,
#   <matplotlib.axis.YTick at 0x1fef558c3d0>,
#   <matplotlib.axis.YTick at 0x1fef558da60>,
#   <matplotlib.axis.YTick at 0x1fef512d280>],
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %%
plt.plot(x,y)
plt.xticks([1,2,3], fontsize= 15)
plt.yticks([3,6,9,12], fontsize=20)
plt.show()
